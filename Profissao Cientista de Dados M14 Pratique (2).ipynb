# %% [markdown]
# # **MÓDULO 14 - Exercício**
# # Pré Processamento dos Dados - A primeira etapa Pré Modelagem

# %% [markdown]
# Para nossa atividade usaremos uma base de churn também, porém essa base não diz respeito a serviços bancários e sim serviços de internet, telefone e tv - Telecomunicação.
#
# Vamos realizar aqui as etapas de limpeza e tratamento de dados vistos durante a aula, porém aplicados a essa base nova.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Lembrem-se sempre de alterar a importação dos dados de acordo com o diretório de vocês.
df = pd.read_csv(r"C:\Users\bianc\PycharmProjects\PythonProject\.venv\Projetos EBAC\8. Pré-Modelagem_1\CHURN_TELECON_MOD08_TAREFA.csv", delimiter=';')

df.head(10)
# Out:
#    customerID  Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 0  7590-VHVEG  Female      0    Yes         No                   1
# 1  5575-GNVDE    Male      0     No         No                  34
# 2  3668-QPYBK    Male      0     No         No                   2
# 3  7795-CFOCW    Male      0     No         No                  45
# 4  9237-HQITU     NaN      0     No         No                   2
# 5  9305-CDSKC     NaN      0     No         No                   8
# 6  1452-KIOVK     NaN      0     No        Yes                  22
# 7  6713-OKOMC     NaN      0     No         No                  10
# 8  7892-POOKP     NaN      0    Yes         No                  28
# 9  6388-TABGU     NaN      0     No        Yes                  62
#
#   PhoneService Servico_Internet Servico_Seguranca Suporte_Tecnico StreamingTV  \
# 0           No              DSL                No              No          No
# ...

# %% [markdown]
# Legenda dos dados:
#
# *   **CustomerID** : Esse é o ID único de cada cliente nosso da rede de produtos de telecomunicação.
#
# *   **Genero** : O genero dos nossos clientes.
#
# *   **Idoso** : Se nosso cliente tem acima de 60 anos ou não. (Sim = 1 | Não = 0)
#
# *   **Casado** : Se nosso cliente é casado ou não.
#
# *   **Dependents** : Se cliente tem dependentes.
#
# *   **Tempo_como_Cliente** : Tempo em meses que nosso cliente está com a nossa empresa.
#
# *   **PhoneService** : Se ele contratou serviço telefônico com a nossa empresa.
#
# *   **Servico_Internet** : Qual o tipo de serviço de internet contratado.
#
# *   **Servico_Seguranca** : Se ele contratou serviço de segurança com a nossa empresa.
#
# *   **Suporte_Tecnico** : Se já acionou o suporte técnico.
#
# *   **StreamingTV** : Se ele contratou serviço de streaming para TV.
#
# *   **Tipo_Contrato** : Qual o tipo de contrato dos nossos clientes, se era mensal, anual etc.
#
# *   **Tipo_Contrato** : Qual o tipo de contrato dos nossos clientes, se era mensal, anual etc.
#
# *   **PaymentMethod** : Forma de Pagamento.
#
# *   **Pagamento_Mensal** : Quanto o cliente pagava mensalmente.
#
# *   **Total_Pago** : Total já pago pelo cliente para nossa companhia.
#
# *   **Churn** : Nossa coluna mais importante, se nosso cliente nos abandonou ou não.

# %% [markdown]
# # 1 - Carregue a base, verifique se os tipos de dados estão de acordo com cada coluna e caso não estejam realize a transformação dos tipos de dados.

# %%
df.dtypes
# Out:
# customerID                str
# Genero                    str
# Idoso                   int64
# Casado                    str
# Dependents                str
# Tempo_como_Cliente      int64
# PhoneService              str
# Servico_Internet          str
# Servico_Seguranca         str
# Suporte_Tecnico           str
# StreamingTV               str
# Tipo_Contrato             str
# PaymentMethod             str
# Pagamento_Mensal      float64
# Total_Pago            float64
# Churn                     str
# dtype: object

# %% [markdown]
# # 2 - Esse exercício faremos por etapas:
# A) Verifique se temos colunas com dados faltantes e traga a % dos dados faltantes por coluna.

# %%
df.isnull().sum()
# Out:
# customerID               0
# Genero                  12
# Idoso                    0
# Casado                   0
# Dependents               0
# Tempo_como_Cliente       0
# PhoneService          1482
# Servico_Internet         0
# Servico_Seguranca        0
# Suporte_Tecnico          0
# StreamingTV              0
# Tipo_Contrato            0
# PaymentMethod            0
# Pagamento_Mensal       325
# Total_Pago               0
# Churn                    5
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# customerID             0.00
# Genero                 0.48
# Idoso                  0.00
# Casado                 0.00
# Dependents             0.00
# Tempo_como_Cliente     0.00
# PhoneService          59.28
# Servico_Internet       0.00
# Servico_Seguranca      0.00
# Suporte_Tecnico        0.00
# StreamingTV            0.00
# Tipo_Contrato          0.00
# PaymentMethod          0.00
# Pagamento_Mensal      13.00
# Total_Pago             0.00
# Churn                  0.20
# dtype: float64

# %% [markdown]
# B) Exclua nessa etapa as linhas das colunas com dados faltantes que você analisar que esse método é o ideal. Justifique o motivo de estar excluindo essas linhas.

# %%
df[df['Genero'].isnull()]
# Out:
#     customerID Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 4   9237-HQITU    NaN      0     No         No                   2
# 5   9305-CDSKC    NaN      0     No         No                   8
# 6   1452-KIOVK    NaN      0     No        Yes                  22
# 7   6713-OKOMC    NaN      0     No         No                  10
# 8   7892-POOKP    NaN      0    Yes         No                  28
# 9   6388-TABGU    NaN      0     No        Yes                  62
# 10  9763-GRSKD    NaN      0    Yes        Yes                  13
# 11  7469-LKBCI    NaN      0     No         No                  16
# 12  8091-TTVAX    NaN      0    Yes         No                  58
# 13  0280-XJGEX    NaN      0     No         No                  49
# 14  5129-JLPIS    NaN      0     No         No                  25
# 15  3655-SNQYZ    NaN      0    Yes        Yes                  69
#
#    PhoneService Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# ...

# %%
df.dropna(subset=['Genero'], inplace=True)  # a exclusão dos dados de gênero faltantes resultará na também exclusão dos dados de Churn faltantes

# %% [markdown]
# C) Nessa etapa substitua pela média, mediana ou moda as linhas das colunas com valores faltantes que você analisou e entendeu que esse era o melhor método. Não se esqueça de justificar sua escolha.

# %%
df['Pagamento_Mensal'].describe()
# Out:
# count    2175.000000
# mean       65.607563
# std        29.931520
# min        18.400000
# 25%        39.500000
# 50%        71.450000
# 75%        90.250000
# max       118.650000
# Name: Pagamento_Mensal, dtype: float64

# %%
df.fillna({'Pagamento_Mensal':df['Total_Pago']/df['Tempo_como_Cliente']}, inplace=True)  # o valor de pagamento mensal é proporcional ao total pago dividido pelo tempo como cliente apesar de não ser um valor exato, a aproximação é melhor do que a utilização das estatísticas
# Out:
#       customerID  Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 0     7590-VHVEG  Female      0    Yes         No                   1
# 1     5575-GNVDE    Male      0     No         No                  34
# 2     3668-QPYBK    Male      0     No         No                   2
# 3     7795-CFOCW    Male      0     No         No                  45
# 16    8191-XWSZG       F      0     No         No                  52
# ...          ...     ...    ...    ...        ...                 ...
# 2495  6188-UXBBR  Female      0    Yes         No                  38
# 2496  2333-KWEWW    Male      0     No         No                  18
# 2497  5702-SKUOB  Female      0    Yes         No                   4
# 2498  1134-YWTYF    Male      0    Yes         No                  27
# 2499  6061-GWWAV    Male      0     No        Yes                  41
#
#      PhoneService Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID               0
# Genero                   0
# Idoso                    0
# Casado                   0
# Dependents               0
# Tempo_como_Cliente       0
# PhoneService          1482
# Servico_Internet         0
# Servico_Seguranca        0
# Suporte_Tecnico          0
# StreamingTV              0
# Tipo_Contrato            0
# PaymentMethod            0
# Pagamento_Mensal         0
# Total_Pago               0
# Churn                    0
# dtype: int64

# %% [markdown]
# **Dica variáveis numéricas:** Não se esqueça de verificar a distrbuição dos dados, média e mediana.

# %% [markdown]
# **Dica variáveis categóricas:** Caso precise substituir uma variável categórica utilize um gráfico de barras para verificar a que mais aparece e utilizar ela na substituição.
# Ou você pode optar por excluir a coluna, mas justifique sua escolha.
#
# Caso opte por substituir você pode utilizar a função fillna:
# df['SUACOLUNA'].fillna("VALOR QUE SUBSTITUIRA O NULO", inplace=True)
# Ela funcionará como a replace.

# %%
df['PhoneService'].describe()
# Out:
# count     1006
# unique       2
# top        Yes
# freq       920
# Name: PhoneService, dtype: object

# %%
df.fillna({'PhoneService': 'Yes'},inplace=True)  # substituindo os valores faltantes pelo valor que mais aparece
# Out:
#       customerID  Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 0     7590-VHVEG  Female      0    Yes         No                   1
# 1     5575-GNVDE    Male      0     No         No                  34
# 2     3668-QPYBK    Male      0     No         No                   2
# 3     7795-CFOCW    Male      0     No         No                  45
# 16    8191-XWSZG       F      0     No         No                  52
# ...          ...     ...    ...    ...        ...                 ...
# 2495  6188-UXBBR  Female      0    Yes         No                  38
# 2496  2333-KWEWW    Male      0     No         No                  18
# 2497  5702-SKUOB  Female      0    Yes         No                   4
# 2498  1134-YWTYF    Male      0    Yes         No                  27
# 2499  6061-GWWAV    Male      0     No        Yes                  41
#
#      PhoneService Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID            0
# Genero                0
# Idoso                 0
# Casado                0
# Dependents            0
# Tempo_como_Cliente    0
# PhoneService          0
# Servico_Internet      0
# Servico_Seguranca     0
# Suporte_Tecnico       0
# StreamingTV           0
# Tipo_Contrato         0
# PaymentMethod         0
# Pagamento_Mensal      0
# Total_Pago            0
# Churn                 0
# dtype: int64

# %% [markdown]
# # 3 - Verifique se encontramos valores digitados incorretamente, ou com letras maiusculas ou minusculas, ou até mesmo mesmos valores porém escritos de forma dirente e corrija.

# %%
df['Genero'] = df['Genero'].str.title()
df['Genero'].unique()
# Out:
# <StringArray>
# ['Female', 'Male', 'F', 'M']
# Length: 4, dtype: str

# %%
df['Genero'] = df['Genero'].replace('F', 'Female')
df['Genero'] = df['Genero'].replace('M', 'Male')
df['Genero'].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df['Servico_Internet'].unique()
# Out:
# <StringArray>
# ['DSL', 'No', 'Fiber optic', 'dsl']
# Length: 4, dtype: str

# %%
df['Servico_Internet'] = df['Servico_Internet'].replace('dsl', 'DSL')

# %%
df[['Casado','Dependents','PhoneService','Churn']] = df[['Casado','Dependents','PhoneService','Churn']].replace('Yes', 1)
df[['Casado','Dependents','PhoneService','Churn']] = df[['Casado','Dependents','PhoneService','Churn']].replace('No', 0)
df.head()
# Out:
#     customerID  Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 0   7590-VHVEG  Female      0      1          0                   1
# 1   5575-GNVDE    Male      0      0          0                  34
# 2   3668-QPYBK    Male      0      0          0                   2
# 3   7795-CFOCW    Male      0      0          0                  45
# 16  8191-XWSZG  Female      0      0          0                  52
#
#    PhoneService Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# 0             0              DSL                   No                   No
# 1             1              DSL                  Yes                   No
# 2             1              DSL                  Yes                   No
# 3             0              DSL                  Yes                  Yes
# 16            1               No  No internet service  No internet service
#
#             StreamingTV   Tipo_Contrato              PaymentMethod  \
# ...

# %%
df.to_csv('CHURN_TELECON_PROCESSADO',index=False)

# %% [markdown]
# # [EXTRA] 4 - Caso deseje, para manter um padrão na sua base, renomeie as colunas ou deixando em português, ou inglês.
